# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#NYC" data-toc-modified-id="NYC-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>NYC</a></span><ul class="toc-item"><li><span><a href="#Extraction-of-AirBnB-datasets-(NYC)" data-toc-modified-id="Extraction-of-AirBnB-datasets-(NYC)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Extraction of AirBnB datasets (NYC)</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span></li><li><span><a href="#Data-Processing" data-toc-modified-id="Data-Processing-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Data Processing</a></span><ul class="toc-item"><li><span><a href="#Residual-Plots" data-toc-modified-id="Residual-Plots-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Residual Plots</a></span></li><li><span><a href="#Multicollinearity" data-toc-modified-id="Multicollinearity-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Multicollinearity</a></span></li><li><span><a href="#Feature-Selection-and-GridSearch" data-toc-modified-id="Feature-Selection-and-GridSearch-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Feature Selection and GridSearch</a></span></li></ul></li><li><span><a href="#Regression-analysis-(model-building)" data-toc-modified-id="Regression-analysis-(model-building)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Regression analysis (model building)</a></span><ul class="toc-item"><li><span><a href="#Phase-1---With-All-Features" data-toc-modified-id="Phase-1---With-All-Features-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Phase 1 - With All Features</a></span><ul class="toc-item"><li><span><a href="#K-Fold-Cross-Validation" data-toc-modified-id="K-Fold-Cross-Validation-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>K-Fold Cross Validation</a></span></li><li><span><a href="#Polynomial-Transformation" data-toc-modified-id="Polynomial-Transformation-1.4.1.2"><span class="toc-item-num">1.4.1.2&nbsp;&nbsp;</span>Polynomial Transformation</a></span></li><li><span><a href="#Model-Prediction" data-toc-modified-id="Model-Prediction-1.4.1.3"><span class="toc-item-num">1.4.1.3&nbsp;&nbsp;</span>Model Prediction</a></span></li></ul></li><li><span><a href="#Phase-2---Without-unnecessary-Features" data-toc-modified-id="Phase-2---Without-unnecessary-Features-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Phase 2 - Without unnecessary Features</a></span><ul class="toc-item"><li><span><a href="#K-Fold-Cross-Validation" data-toc-modified-id="K-Fold-Cross-Validation-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>K-Fold Cross Validation</a></span></li><li><span><a href="#Polynomial-Transformation" data-toc-modified-id="Polynomial-Transformation-1.4.2.2"><span class="toc-item-num">1.4.2.2&nbsp;&nbsp;</span>Polynomial Transformation</a></span></li><li><span><a href="#Model-Prediction" data-toc-modified-id="Model-Prediction-1.4.2.3"><span class="toc-item-num">1.4.2.3&nbsp;&nbsp;</span>Model Prediction</a></span></li></ul></li></ul></li><li><span><a href="#Model-evaluation-and-testing" data-toc-modified-id="Model-evaluation-and-testing-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Model evaluation and testing</a></span></li></ul></li><li><span><a href="#Seattle" data-toc-modified-id="Seattle-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Seattle</a></span><ul class="toc-item"><li><span><a href="#Extraction-of-AirBnB-datasets-(Seattle)" data-toc-modified-id="Extraction-of-AirBnB-datasets-(Seattle)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Extraction of AirBnB datasets (Seattle)</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span></li><li><span><a href="#Data-processing" data-toc-modified-id="Data-processing-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Data processing</a></span><ul class="toc-item"><li><span><a href="#Residual-Plots" data-toc-modified-id="Residual-Plots-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Residual Plots</a></span></li><li><span><a href="#Multicollinearity" data-toc-modified-id="Multicollinearity-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Multicollinearity</a></span></li><li><span><a href="#Feature-Selection-and-GridSearch" data-toc-modified-id="Feature-Selection-and-GridSearch-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Feature Selection and GridSearch</a></span></li></ul></li><li><span><a href="#Regression-analysis（model-building)" data-toc-modified-id="Regression-analysis（model-building)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Regression analysis（model building)</a></span><ul class="toc-item"><li><span><a href="#Phase-1---With-All-Features" data-toc-modified-id="Phase-1---With-All-Features-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Phase 1 - With All Features</a></span><ul class="toc-item"><li><span><a href="#K-Fold-Cross-Validation" data-toc-modified-id="K-Fold-Cross-Validation-2.4.1.1"><span class="toc-item-num">2.4.1.1&nbsp;&nbsp;</span>K-Fold Cross Validation</a></span></li><li><span><a href="#Polynomial-Transformation" data-toc-modified-id="Polynomial-Transformation-2.4.1.2"><span class="toc-item-num">2.4.1.2&nbsp;&nbsp;</span>Polynomial Transformation</a></span></li><li><span><a href="#Model-Prediction" data-toc-modified-id="Model-Prediction-2.4.1.3"><span class="toc-item-num">2.4.1.3&nbsp;&nbsp;</span>Model Prediction</a></span></li></ul></li><li><span><a href="#Phase-2---Without-unsignificant-Features" data-toc-modified-id="Phase-2---Without-unsignificant-Features-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Phase 2 - Without unsignificant Features</a></span><ul class="toc-item"><li><span><a href="#K-Fold-Cross-Validation" data-toc-modified-id="K-Fold-Cross-Validation-2.4.2.1"><span class="toc-item-num">2.4.2.1&nbsp;&nbsp;</span>K-Fold Cross Validation</a></span></li><li><span><a href="#Polynomial-Transformation" data-toc-modified-id="Polynomial-Transformation-2.4.2.2"><span class="toc-item-num">2.4.2.2&nbsp;&nbsp;</span>Polynomial Transformation</a></span></li><li><span><a href="#Model-Prediction" data-toc-modified-id="Model-Prediction-2.4.2.3"><span class="toc-item-num">2.4.2.3&nbsp;&nbsp;</span>Model Prediction</a></span></li></ul></li></ul></li><li><span><a href="#Model-evaluation-and-testing" data-toc-modified-id="Model-evaluation-and-testing-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Model evaluation and testing</a></span></li></ul></li><li><span><a href="#Nashville" data-toc-modified-id="Nashville-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Nashville</a></span><ul class="toc-item"><li><span><a href="#Extraction-of-AirBnB-datasets-(Nashville)" data-toc-modified-id="Extraction-of-AirBnB-datasets-(Nashville)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Extraction of AirBnB datasets (Nashville)</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span></li><li><span><a href="#Data-processing" data-toc-modified-id="Data-processing-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Data processing</a></span><ul class="toc-item"><li><span><a href="#Residual-Plots" data-toc-modified-id="Residual-Plots-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Residual Plots</a></span></li><li><span><a href="#Multicollinearity" data-toc-modified-id="Multicollinearity-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Multicollinearity</a></span></li><li><span><a href="#Feature-Selection-and-GridSearch" data-toc-modified-id="Feature-Selection-and-GridSearch-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Feature Selection and GridSearch</a></span></li></ul></li><li><span><a href="#Regression-analysis-(model-building)" data-toc-modified-id="Regression-analysis-(model-building)-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Regression analysis (model building)</a></span><ul class="toc-item"><li><span><a href="#Phase-1---With-All-Features" data-toc-modified-id="Phase-1---With-All-Features-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Phase 1 - With All Features</a></span><ul class="toc-item"><li><span><a href="#K-Fold-Cross-Validation" data-toc-modified-id="K-Fold-Cross-Validation-3.4.1.1"><span class="toc-item-num">3.4.1.1&nbsp;&nbsp;</span>K-Fold Cross Validation</a></span></li><li><span><a href="#Polynomial-Transformation" data-toc-modified-id="Polynomial-Transformation-3.4.1.2"><span class="toc-item-num">3.4.1.2&nbsp;&nbsp;</span>Polynomial Transformation</a></span></li><li><span><a href="#Model-Prediction" data-toc-modified-id="Model-Prediction-3.4.1.3"><span class="toc-item-num">3.4.1.3&nbsp;&nbsp;</span>Model Prediction</a></span></li></ul></li><li><span><a href="#Phase-2---Without-unsignificant-Features" data-toc-modified-id="Phase-2---Without-unsignificant-Features-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Phase 2 - Without unsignificant Features</a></span><ul class="toc-item"><li><span><a href="#K-Fold-Cross-Validation" data-toc-modified-id="K-Fold-Cross-Validation-3.4.2.1"><span class="toc-item-num">3.4.2.1&nbsp;&nbsp;</span>K-Fold Cross Validation</a></span></li><li><span><a href="#Polynomial-Transformation" data-toc-modified-id="Polynomial-Transformation-3.4.2.2"><span class="toc-item-num">3.4.2.2&nbsp;&nbsp;</span>Polynomial Transformation</a></span></li><li><span><a href="#Model-Prediction" data-toc-modified-id="Model-Prediction-3.4.2.3"><span class="toc-item-num">3.4.2.3&nbsp;&nbsp;</span>Model Prediction</a></span></li></ul></li></ul></li><li><span><a href="#Model-evaluation-and-testing" data-toc-modified-id="Model-evaluation-and-testing-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Model evaluation and testing</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# Module Code: 1052761
#
#
# Assignment Report Title: Programming in Python for Data Science
#
#
# Student Number (e.g., 25098635/202083750001): 29805261/202083710036
#
#
# Student Name: Long Xianxuan
#
#
# Date (when work was completed): 2023/5/30
#
#
# Actual hours spent on assignment: 12hrs
#
#
# Assignment evaluation (3 key points): data visualization; regression; house price prediction

# %% [markdown]
# # Introduction
#
# Airbnb is an online marketplace for arranging or offering lodging, primarily homestays, or tourism experiences since 2008.
#
# NYC is the most populous city in the United States and also one of the most popular tourism and business place in the world. Hence we select listings.csv of NYC in 2023, which is the summary information and metrics for listings in New York City (good for visualisations).Also, we select the listing.csv of other two cities: Nashville and Seattle.
#
# Airbnb NYC/Seattle/Nashville 2023 data contains listing activity and metrics. In this kernel, I would like to choose the best prediction model for price. Meanwhile, price feature's relationship examines with others and some data exploratory analysis will be made for each dataset.

# %% [markdown]
# # NYC

# %% [markdown]
# ## Extraction of AirBnB datasets (NYC)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import norm
from scipy import stats
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
from sklearn.metrics import r2_score

# %% [markdown]
# First, data content will be examined.

# %%
nyc_data = pd.read_csv('./data/Task2/AirBnB_NYC.csv')
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3172: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
nyc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42931 entries, 0 to 42930
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              42931 non-null  int64
#  1   name                            42919 non-null  object
#  2   host_id                         42931 non-null  int64
#  3   host_name                       42926 non-null  object
#  4   neighbourhood_group             42931 non-null  object
#  5   neighbourhood                   42931 non-null  object
#  6   latitude                        42931 non-null  float64
#  7   longitude                       42931 non-null  float64
#  8   room_type                       42931 non-null  object
#  9   price                           42931 non-null  int64
#  10  minimum_nights                  42931 non-null  int64
#  11  number_of_reviews               42931 non-null  int64
# ...

# %%
nyc_data.head()
# Out:
#      id                                         name  host_id  host_name  \
# 0  2595                        Skylit Midtown Castle     2845   Jennifer
# 1  5121                              BlissArtsSpace!     7356      Garon
# 2  5203           Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 3  5178             Large Furnished Room Near B'way　     8967   Shunichi
# 4  5136  Large Sunny Brooklyn Duplex, Patio + Garden     7378    Rebecca
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan             Midtown  40.75356  -73.98559
# 1            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 2           Manhattan     Upper West Side  40.80380  -73.96751
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4            Brooklyn         Sunset Park  40.66265  -73.99454
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
nyc_data.isnull().sum()
# Out:
# id                                    0
# name                                 12
# host_id                               0
# host_name                             5
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10304
# reviews_per_month                 10304
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           42930
# dtype: int64

# %% [markdown]
# Above table shows that, there are some missing data for some features. They will be detailed later.

# %% [markdown]
# ## Exploratory Data Analysis
#
# The first graph is about the relationship between ``price`` and ``room type``. The ``Shared room`` price is always lower than 2000 dollars. On the other hand, the ``private room`` and the ``entire home`` have the highest price in some. Hotel room has the lowest price amoung these four types of rooms.

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='room_type', y='price', data=nyc_data)

plt.xlabel("Room Type", size=13)
plt.ylabel("Price", size=13)
plt.title("Room Type vs Price",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Room Type vs Price')

# %% [markdown]
# Below graph shows details about ``price`` and ``room type`` based on ``neighborhood group``. The highest price of ``Private Room`` ``Hotel Room``and ``Shared Room``is in the same area which is ``Manhattan``. Also, Brooklyn has very-high prices in ``Entire Home/Apt``.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="room_type", y="price",
            hue="neighbourhood_group", size="neighbourhood_group",
            sizes=(50, 200), palette="Dark2", data=nyc_data)

plt.xlabel("Room Type", size=13)
plt.ylabel("Price", size=13)
plt.title("Room Type vs Price vs Neighbourhood Group",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Room Type vs Price vs Neighbourhood Group')

# %% [markdown]
# Another graph is about ``price`` vs ``number of reviews`` based on ``neighborhood group``. It shows us the lowest prices have higher reviews than the higher prices. It shows negative correlation between ``price`` and ``number of reviews``. Also ``Manhattan``, ``Staten island`` and ``Brooklyn`` areas have higher reviews than others.

# %%
plt.figure(figsize=(15,10))
sns.set_palette("Set1")

sns.lineplot(x='price', y='number_of_reviews', 
             data=nyc_data[nyc_data['neighbourhood_group']=='Brooklyn'],
             label='Brooklyn')
sns.lineplot(x='price', y='number_of_reviews', 
             data=nyc_data[nyc_data['neighbourhood_group']=='Manhattan'],
             label='Manhattan')
sns.lineplot(x='price', y='number_of_reviews', 
             data=nyc_data[nyc_data['neighbourhood_group']=='Queens'],
             label='Queens')
sns.lineplot(x='price', y='number_of_reviews', 
             data=nyc_data[nyc_data['neighbourhood_group']=='Staten Island'],
             label='Staten Island')
sns.lineplot(x='price', y='number_of_reviews', 
             data=nyc_data[nyc_data['neighbourhood_group']=='Bronx'],
             label='Bronx')
plt.xlabel("Price", size=13)
plt.ylabel("Number of Reviews", size=13)
plt.title("Price vs Number of Reviews vs Neighbourhood Group",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Price vs Number of Reviews vs Neighbourhood Group')

# %% [markdown]
# We can also explore the minimum price, maximum price, average price and the median price per listing.

# %%
min_price = nyc_data['price'].min()
max_price = nyc_data['price'].max()
mean_price = nyc_data['price'].mean()
median_price = nyc_data['price'].median()

print('Minimum price per listing is %d$.' % (min_price))
print('Maximum price per listing is %d$' % (max_price))
print('Average price per listing is %d$.' % (mean_price))
print('Median price per listing is %d$.' % (median_price))
# Out:
# Minimum price per listing is 0$.
# Maximum price per listing is 99000$
# Average price per listing is 200$.
# Median price per listing is 125$.

# %% [markdown]
# Before examining ``price`` feature, categorical variables will be mapped with help of ``cat.code``. This will assist to make easier and comprehensible data analysis.

# %%
nyc_data['neighbourhood_group']= nyc_data['neighbourhood_group'].astype("category").cat.codes
nyc_data['neighbourhood'] = nyc_data['neighbourhood'].astype("category").cat.codes
nyc_data['room_type'] = nyc_data['room_type'].astype("category").cat.codes
nyc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42931 entries, 0 to 42930
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              42931 non-null  int64
#  1   name                            42919 non-null  object
#  2   host_id                         42931 non-null  int64
#  3   host_name                       42926 non-null  object
#  4   neighbourhood_group             42931 non-null  int8
#  5   neighbourhood                   42931 non-null  int16
#  6   latitude                        42931 non-null  float64
#  7   longitude                       42931 non-null  float64
#  8   room_type                       42931 non-null  int8
#  9   price                           42931 non-null  int64
#  10  minimum_nights                  42931 non-null  int64
#  11  number_of_reviews               42931 non-null  int64
# ...

# %%
plt.figure(figsize=(10,10))
sns.distplot(nyc_data['price'], fit=norm)
plt.title("Price Distribution Plot",size=15, weight='bold')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Price Distribution Plot')

# %% [markdown]
# The above distribution graph shows that there is a right-skewed distribution on ``price``. This means there is a positive skewness. Log transformation will be used to make this feature less skewed. This will help to make easier interpretation and better statistical analysis
#
# Since division by zero is a problem, ``log+1`` transformation would be better.

# %%
nyc_data['price_log'] = np.log(nyc_data.price+1)

# %% [markdown]
# With help of log transformation, now, price feature have normal distribution.

# %%
plt.figure(figsize=(12,10))
sns.distplot(nyc_data['price_log'], fit=norm)
plt.title("Log-Price Distribution Plot",size=15, weight='bold')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Log-Price Distribution Plot')

# %% [markdown]
# In below graph, the good fit indicates that normality is a reasonable approximation.

# %%
plt.figure(figsize=(7,7))
stats.probplot(nyc_data['price_log'], plot=plt)
plt.show()

# %% [markdown]
# ## Data Processing

# %% [markdown]
# Now it is time to prepare data for modeling. First, non-nominal data and old ``price`` feature will be eliminated.

# %%
nyc_model = nyc_data.drop(columns=['name','id' ,'host_id','host_name', 
                                   'last_review','price'])
nyc_model.isnull().sum()
# Out:
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10304
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           42930
# price_log                             0
# dtype: int64

# %%
#find percentage of missing values for each column
nyc_missing_data = nyc_data.isnull().mean()*100

#filter out only columns, which have missing values
nyc_missing_data = nyc_missing_data[nyc_missing_data > 0]

#plot the results
nyc_missing_data.plot.bar(title='Missing values per column, %')
# Out:
# <AxesSubplot:title={'center':'Missing values per column, %'}>

# %% [markdown]
# ``Number of reviews`` feature has some missing data. For this feature, missing data will be replaced with mean. Since the data is more symmetric, mean replacement would be better.

# %%
mean = nyc_model['reviews_per_month'].mean()
nyc_model['reviews_per_month'].fillna(mean, inplace=True)
nyc_model.isnull().sum()
# Out:
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           42930
# price_log                             0
# dtype: int64

# %% [markdown]
# Also, due to the proportion of missing values for the feature license is too large, we'd better drop this column directly.

# %%
nyc_model.drop(columns=['license'], inplace=True)
nyc_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42931 entries, 0 to 42930
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             42931 non-null  int8
#  1   neighbourhood                   42931 non-null  int16
#  2   latitude                        42931 non-null  float64
#  3   longitude                       42931 non-null  float64
#  4   room_type                       42931 non-null  int8
#  5   minimum_nights                  42931 non-null  int64
#  6   number_of_reviews               42931 non-null  int64
#  7   reviews_per_month               42931 non-null  float64
#  8   calculated_host_listings_count  42931 non-null  int64
#  9   availability_365                42931 non-null  int64
#  10  number_of_reviews_ltm           42931 non-null  int64
#  11  price_log                       42931 non-null  float64
# ...

# %% [markdown]
# From now on, we have delt with missing values and irrelevant features appropriately. It is time to make more details about data. A correlation table will be created and the Pearson method will be used.

# %%
plt.figure(figsize=(10, 8))
palette = sns.diverging_palette(20, 220, n=256)
corr = nyc_model.corr(method='pearson')
sns.heatmap(corr, annot=True, fmt=".2f", cmap=palette, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.ylim(12, -0.5)
plt.title("Correlation Matrix", size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# The correlation table shows that there is no strong relationship between price and other features. This indicates no feature needed to be taken out of data. This relationship will be detailed with Residual Plots and Multicollinearity.

# %% [markdown]
# ### Residual Plots
#
# Residual Plot is strong method to detect outliers, non-linear data and detecting data for regression models. The below charts show the residual plots for each feature with the ``price``.
#
# An ideal Residual Plot, the red line would be horizontal. Based on the below charts, most features are non-linear. On the other hand, there are not many outliers in each feature. This result led to underfitting. Underfitting can occur when input features do not have a strong relationship to target variables or over-regularized. For avoiding underfitting new data features can be added or regularization weight could be reduced.
#
# In this kernel, since the input feature data could not be increased, Regularized Linear Models will be used for regularization and polynomial transformation will be made to avoid underfitting.

# %%
nyc_model_x, nyc_model_y = nyc_model.iloc[:,:-1], nyc_model.iloc[:,-1]

# %%
f, axes = plt.subplots(5, 2, figsize=(15, 20))
sns.residplot(nyc_model_x.iloc[:,0],nyc_model_y, lowess=True, ax=axes[0, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,1],nyc_model_y, lowess=True, ax=axes[0, 1],
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,2],nyc_model_y, lowess=True, ax=axes[1, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,3],nyc_model_y, lowess=True, ax=axes[1, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,4],nyc_model_y, lowess=True, ax=axes[2, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,5],nyc_model_y, lowess=True, ax=axes[2, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,6],nyc_model_y, lowess=True, ax=axes[3, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,7],nyc_model_y, lowess=True, ax=axes[3, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,8],nyc_model_y, lowess=True, ax=axes[4, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nyc_model_x.iloc[:,9],nyc_model_y, lowess=True, ax=axes[4, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
plt.setp(axes, yticks=[])
plt.tight_layout()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Multicollinearity
#
# Multicollinearity will help to measure the relationship between explanatory variables in multiple regression. If there is multicollinearity occurs, these highly related input variables should be eliminated from the model.
#
# In this kernel, multicollinearity will be control with ``Eigen vector values`` results.

# %%
#Eigen vector of a correlation matrix.
multicollinearity, V=np.linalg.eig(corr)
multicollinearity
# Out:
# array([2.51790694, 1.6971577 , 1.38359585, 0.1611365 , 1.15915344,
#        1.08460754, 0.40037664, 0.45598257, 0.90251008, 0.83004182,
#        0.67561817, 0.73191275])

# %% [markdown]
# None one of the eigenvalues of the correlation matrix is close to zero. It means that there is no multicollinearity exists in the data.

# %% [markdown]
# ### Feature Selection and GridSearch
#
# First, ``Standard Scaler`` technique will be used to normalize the data set. Thus, each feature has 0 mean and 1 standard deviation.

# %% [markdown]
# To avoid datatype error later on, we need to check the datatype for each column first.

# %%
nyc_model_x.dtypes
# Out:
# neighbourhood_group                  int8
# neighbourhood                       int16
# latitude                          float64
# longitude                         float64
# room_type                            int8
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# dtype: object

# %% [markdown]
# It's correct because there is no string. All features are float or int.
# The following code standardizes the data, using the StandardScaler class and its fit_Transform() method.
# Standardization is a common data preprocessing technology, which aims to convert data into standard normal distribution with zero mean and unit variance. Standardization can help eliminate dimensional differences between features, allowing different features to have the same weight in the model. This helps to improve the training effectiveness and performance of the model.
# Here, StandardScaler is a class used for data standardization. It can calculate the mean and standard deviation of data and scale the data according to the standard normal distribution. fit_Transform() method is used to calculate and apply standardized transformations, which receive raw data as input and return standardized data.

# %%
scaler = StandardScaler()
nyc_model_x = scaler.fit_transform(nyc_model_x)

# %% [markdown]
# Secondly, data will be split in a 70–30 ratio

# %%
X_train, X_test, y_train, y_test = train_test_split(nyc_model_x, nyc_model_y, test_size=0.3,random_state=42)

# %% [markdown]
# Now it is time to build a ``feature importance`` graph. For this ``Extra Trees Classifier`` method will be used. In the below code, ``lowess=True`` makes sure the lowest regression line is drawn.

# %%
lab_enc = preprocessing.LabelEncoder()

feature_model = ExtraTreesClassifier(n_estimators=50)
feature_model.fit(X_train,lab_enc.fit_transform(y_train))

plt.figure(figsize=(7,7))
feat_importances = pd.Series(feature_model.feature_importances_, index=nyc_model.iloc[:,:-1].columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# The above graph shows the feature importance of dataset. According to that, ``neighborhood group`` has the lowest importance on the model. Under this result, the model building will be made in 2 phases. In the first phase, models will be built within all features and in the second phase, models will be built without ``neighborhood group`` and ``room type`` features.

# %% [markdown]
# ## Regression analysis (model building)
#
# ### Phase 1 - With All Features
#
# Correlation matrix, Residual Plots and Multicollinearity results show that underfitting occurs on the model and there is no multicollinearity on the independent variables. Avoiding underfitting will be made with ``Polynomial Transformation`` since no new features can not be added or replaced with the existing ones.
#
# In model building section, `Linear Regression`, `Ridge Regression`, `Lasso Regression`, and `ElasticNet Regression` models will be built. These models will be used to avoiding plain ``Linear Regression`` and show the results with a little of regularization.
#
# First, `GridSearchCV` algorithm will be used to find the best parameters and tuning hyperparameters for each model. In this algorithm ``5-Fold Cross Validation`` and ``Mean Squared Error Regression Loss`` metrics will be used.

# %%
### Linear Regression ###

def linear_reg(input_x, input_y, cv=5):
    ## Defining parameters
    model_LR= LinearRegression()

    parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}

    ## Building Grid Search algorithm with cross-validation and Mean Squared Error score.

    grid_search_LR = GridSearchCV(estimator=model_LR,  
                         param_grid=parameters,
                         scoring='neg_mean_squared_error',
                         cv=cv,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.

    grid_search_LR.fit(input_x, input_y)
    best_parameters_LR = grid_search_LR.best_params_  
    best_score_LR = grid_search_LR.best_score_ 
    print(best_parameters_LR)
    print(best_score_LR)


# linear_reg(nyc_model_x, nyc_model_y)

# %%
### Ridge Regression ###

def ridge_reg(input_x, input_y, cv=5):
    ## Defining parameters
    model_Ridge= Ridge()

    # prepare a range of alpha values to test
    alphas = np.array([1,0.1,0.01,0.001,0.0001,0])
    normalizes= ([True,False])

    ## Building Grid Search algorithm with cross-validation and Mean Squared Error score.

    grid_search_Ridge = GridSearchCV(estimator=model_Ridge,  
                         param_grid=(dict(alpha=alphas, normalize= normalizes)),
                         scoring='neg_mean_squared_error',
                         cv=cv,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.
    grid_search_Ridge.fit(input_x, input_y)
    best_parameters_Ridge = grid_search_Ridge.best_params_  
    best_score_Ridge = grid_search_Ridge.best_score_ 
    print(best_parameters_Ridge)
    print(best_score_Ridge)
    
# ridge_reg(nyc_model_x, nyc_model_y)

# %%
### Lasso Regression ###

def lasso_reg(input_x, input_y, cv=5):
    ## Defining parameters
    model_Lasso= Lasso()

    # prepare a range of alpha values to test
    alphas = np.array([1,0.1,0.01,0.001,0.0001,0])
    normalizes= ([True,False])

    ## Building Grid Search algorithm with cross-validation and Mean Squared Error score.

    grid_search_lasso = GridSearchCV(estimator=model_Lasso,  
                         param_grid=(dict(alpha=alphas, normalize= normalizes)),
                         scoring='neg_mean_squared_error',
                         cv=cv,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.

    grid_search_lasso.fit(input_x, input_y)
    best_parameters_lasso = grid_search_lasso.best_params_  
    best_score_lasso = grid_search_lasso.best_score_ 
    print(best_parameters_lasso)
    print(best_score_lasso)

# lasso_reg(nyc_model_x, nyc_model_y)

# %%
### ElasticNet Regression ###

def elastic_reg(input_x, input_y,cv=5):
    ## Defining parameters
    model_grid_Elastic= ElasticNet()

    # prepare a range of alpha values to test
    alphas = np.array([1,0.1,0.01,0.001,0.0001,0])
    normalizes= ([True,False])

    ## Building Grid Search algorithm with cross-validation and Mean Squared Error score.

    grid_search_elastic = GridSearchCV(estimator=model_grid_Elastic,  
                         param_grid=(dict(alpha=alphas, normalize= normalizes)),
                         scoring='neg_mean_squared_error',
                         cv=cv,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.

    grid_search_elastic.fit(input_x, input_y)
    best_parameters_elastic = grid_search_elastic.best_params_  
    best_score_elastic = grid_search_elastic.best_score_ 
    print(best_parameters_elastic)
    print(best_score_elastic)

# elastic_reg(nyc_model_x, nyc_model_y)

# %% [markdown]
# #### K-Fold Cross Validation
#
# Before model building, 5-Fold Cross Validation will be implemented for validation.

# %%
kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
for train_index, test_index in kfold_cv.split(nyc_model_x,nyc_model_y):
    X_train, X_test = nyc_model_x[train_index], nyc_model_x[test_index]
    y_train, y_test = nyc_model_y[train_index], nyc_model_y[test_index]

# %% [markdown]
# #### Polynomial Transformation
# The polynomial transformation will be made with a second degree which adding the square of each feature.

# %%
Poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_train = Poly.fit_transform(X_train)
X_test = Poly.fit_transform(X_test)

# %% [markdown]
# #### Model Prediction

# %%
##Linear Regression
lr = LinearRegression(copy_X= True, fit_intercept = True, normalize = True)
lr.fit(X_train, y_train)
lr_pred= lr.predict(X_test)

#Ridge Model
ridge_model = Ridge(alpha = 0.008, normalize = True)
ridge_model.fit(X_train, y_train)             
pred_ridge = ridge_model.predict(X_test) 

#Lasso Model
Lasso_model = Lasso(alpha = 0.001, normalize =False)
Lasso_model.fit(X_train, y_train)
pred_Lasso = Lasso_model.predict(X_test) 

#ElasticNet Model
model_enet = ElasticNet(alpha = 0.01, normalize=False)
model_enet.fit(X_train, y_train) 
pred_test_enet= model_enet.predict(X_test)

# %% [markdown]
# ### Phase 2 - Without unnecessary Features
#
# All steps from Phase 1, will be repeated in this Phase. The difference is, ``neighbourhood_group`` feature will be eliminated.

# %%
nyc_model_xx= nyc_model.drop(columns=['neighbourhood_group'])

# %%
nyc_model_xx, nyc_model_yx = nyc_model_xx.iloc[:,:-1], nyc_model_xx.iloc[:,-1]
X_train_x, X_test_x, y_train_x, y_test_x = train_test_split(nyc_model_xx, nyc_model_yx, test_size=0.1,random_state=42)

# %%
scaler = StandardScaler()
nyc_model_xx = scaler.fit_transform(nyc_model_xx)

# %%
### Linear Regression ###
linear_reg(nyc_model_xx, nyc_model_yx, cv=4)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# -0.4077964730403046

# %%
### Ridge Regression ###
ridge_reg(nyc_model_xx, nyc_model_yx, cv=4)
# Out:
# {'alpha': 0.01, 'normalize': True}
# -0.40759860996342173

# %%
### Lasso Regression ###
lasso_reg(nyc_model_xx, nyc_model_yx, cv=4)
# Out:
# {'alpha': 0.01, 'normalize': False}
# -0.4065350741083201

# %%
### ElasticNet Regression ###
elastic_reg(nyc_model_xx, nyc_model_yx, cv=4)
# Out:
# {'alpha': 0.01, 'normalize': False}
# -0.4069871699806735

# %% [markdown]
# #### K-Fold Cross Validation
# Before model building, 5-Fold Cross Validation will be implemented for validation.

# %%
kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
for train_index, test_index in kfold_cv.split(nyc_model_xx,nyc_model_yx):
    X_train_x, X_test_x = nyc_model_xx[train_index], nyc_model_xx[test_index]
    y_train_x, y_test_x = nyc_model_yx[train_index], nyc_model_yx[test_index]

# %% [markdown]
# #### Polynomial Transformation

# %%
Poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_train_x = Poly.fit_transform(X_train_x)
X_test_x = Poly.fit_transform(X_test_x)

# %% [markdown]
# #### Model Prediction

# %%
###Linear Regression
lr_x = LinearRegression(copy_X= True, fit_intercept = True, normalize = True)
lr_x.fit(X_train_x, y_train_x)
lr_pred_x= lr_x.predict(X_test_x)

###Ridge
ridge_x = Ridge(alpha = 0.008, normalize = True)
ridge_x.fit(X_train_x, y_train_x)           
pred_ridge_x = ridge_x.predict(X_test_x) 

###Lasso
Lasso_x = Lasso(alpha = 0.001, normalize =False)
Lasso_x.fit(X_train_x, y_train_x)
pred_Lasso_x = Lasso_x.predict(X_test_x) 

##ElasticNet
model_enet_x = ElasticNet(alpha = 0.01, normalize=False)
model_enet_x.fit(X_train_x, y_train_x) 
pred_train_enet_x= model_enet_x.predict(X_train_x)
pred_test_enet_x= model_enet_x.predict(X_test_x)

# %% [markdown]
# ## Model evaluation and testing
#
# In this part, 3 metrics will be calculated for evaluating predictions.
#
# * ``Mean Absolute Error (MAE)``    shows the difference between predictions and actual values.
#
# * ``Root Mean Square Error (RMSE)`` shows how accurately the model predicts the response.
#
# *                   ``R^2``  will be calculated to find the goodness of fit measure.

# %%
print('-------------Linear Regression-----------')

print('--Phase-1--')
print('MAE: %f'% mean_absolute_error(y_test, lr_pred))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test, lr_pred)))   
print('R2 %f' % r2_score(y_test, lr_pred))

print('--Phase-2--')
print('MAE: %f'% mean_absolute_error(y_test_x, lr_pred_x))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test_x, lr_pred_x)))   
print('R2 %f' % r2_score(y_test_x, lr_pred_x))

print('---------------Ridge ---------------------')

print('--Phase-1--')
print('MAE: %f'% mean_absolute_error(y_test, pred_ridge))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test, pred_ridge)))   
print('R2 %f' % r2_score(y_test, pred_ridge))

print('--Phase-2--')
print('MAE: %f'% mean_absolute_error(y_test_x, pred_ridge_x))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test_x, pred_ridge_x)))   
print('R2 %f' % r2_score(y_test_x, pred_ridge_x))

print('---------------Lasso-----------------------')

print('--Phase-1--')
print('MAE: %f' % mean_absolute_error(y_test, pred_Lasso))
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test, pred_Lasso)))
print('R2 %f' % r2_score(y_test, pred_Lasso))

print('--Phase-2--')
print('MAE: %f' % mean_absolute_error(y_test_x, pred_Lasso_x))
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test_x, pred_Lasso_x)))
print('R2 %f' % r2_score(y_test_x, pred_Lasso_x))

print('---------------ElasticNet-------------------')

print('--Phase-1 --')
print('MAE: %f' % mean_absolute_error(y_test,pred_test_enet)) #RMSE
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test,pred_test_enet))) #RMSE
print('R2 %f' % r2_score(y_test, pred_test_enet))

print('--Phase-2--')
print('MAE: %f' % mean_absolute_error(y_test_x,pred_test_enet_x)) #RMSE
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test_x,pred_test_enet_x))) #RMSE
print('R2 %f' % r2_score(y_test_x, pred_test_enet_x))
# Out:
# -------------Linear Regression-----------
# --Phase-1--
# MAE: 0.424165
# RMSE: 0.600387
# R2 0.421338
# --Phase-2--
# MAE: 0.428221
# RMSE: 0.605149
# R2 0.412122
# ---------------Ridge ---------------------
# --Phase-1--
# MAE: 0.424206
# RMSE: 0.600190
# R2 0.421718
# --Phase-2--
# MAE: 0.428217
# RMSE: 0.604927
# R2 0.412553
# ---------------Lasso-----------------------
# --Phase-1--
# MAE: 0.424048
# RMSE: 0.600071
# R2 0.421946
# --Phase-2--
# MAE: 0.428080
# RMSE: 0.604837
# R2 0.412728
# ---------------ElasticNet-------------------
# --Phase-1 --
# MAE: 0.425585
# RMSE: 0.602567
# R2 0.417128
# --Phase-2--
# MAE: 0.429155
# RMSE: 0.606748
# R2 0.409011

# %% [markdown]
# The results show that all models have similar prediction results. Phase 1 and 2 have a similar performance for each metric. Phase1 and Phase2 results are consistent, indicating stability in model performance.
#
#
# ##### Mean Absolute Error (MAE):
# MAE represents the average magnitude of the errors between the predicted house prices and the actual house prices.
# For NYC, the MAE values range from approximately 0.424 to 0.425 in phase 1 and phase 2, respectively.
# Lower MAE values indicate better predictive performance, as it represents smaller average errors.
#
#
# ##### Root Mean Squared Error (RMSE):
# RMSE is another measure of the prediction error that considers both the magnitude and direction of the errors.
# It is calculated by taking the square root of the average of squared differences between predicted and actual house prices.
# For NYC, the RMSE values range from approximately 0.596 to 0.603 in phase 1 and phase 2, respectively.
# Similar to MAE, lower RMSE values indicate better predictive performance, as it represents smaller overall errors.
#
#
# ##### R2:
# The R2 values range from 0.417 to 0.421, indicating that the models can explain around 42% of the variance in the house prices in NYC.This suggests that the models capture a significant portion of the underlying factors influencing house prices in NYC, but there is still room for improvement to increase the predictive power.

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4, figsize=(30, 20))
fig.suptitle('True Values vs Predictions')

ax1.scatter(y_test, lr_pred)
ax1.set_title('Linear Regression - Phase-1')

ax2.scatter(y_test, pred_ridge)
ax2.set_title('Ridge - Phase-1')

ax3.scatter(y_test, pred_Lasso)
ax3.set_title('Lasso - Phase-1')

ax4.scatter(y_test, pred_test_enet)
ax4.set_title('ElasticNet - Phase-1')

ax5.scatter(y_test_x, lr_pred_x)
ax5.set_title('Linear Regression - Phase-2')

ax6.scatter(y_test_x, pred_ridge_x)
ax6.set_title('Ridge - Phase-2')

ax7.scatter(y_test_x, pred_Lasso_x)
ax7.set_title('Lasso - Phase-2')

ax8.scatter(y_test_x, pred_test_enet_x)
ax8.set_title('ElasticNet - Phase-2')

for ax in fig.get_axes():
    ax.set(xlabel='True Values', ylabel='Predictions')

# %% [markdown]
# The last graph is about the difference between True Values vs Prediction for Phase 1 and Phase 2. The difference between the two phases among these four models are remarkable.

# %% [markdown]
# # Seattle

# %% [markdown]
# ## Extraction of AirBnB datasets (Seattle)

# %%
Seattle_data = pd.read_csv('./data/Task2/AirBnB_Seattle.csv')

# %%
Seattle_data.head()
# Out:
#        id                                              name  host_id  \
# 0  879181                  In Jimi Hendrix's neighborhood 3   287172
# 1    6606               Fab, private seattle urban cottage!    14942
# 2  902609                Entire guest suite in West Seattle  3264544
# 3    9419               Glorious sun room w/ memory foambed    30559
# 4  226536  Serene Room in Sunny Cottage near Discovery Park   209571
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0      Laura         Central Area       Atlantic  47.60096 -122.30190
# 1      Joyce  Other neighborhoods    Wallingford  47.65444 -122.33629
# 2      Fabio             Delridge  Highland Park  47.52383 -122.35287
# 3  Angielena  Other neighborhoods     Georgetown  47.55017 -122.31937
# 4     Cheryl             Magnolia    Lawton Park  47.66133 -122.40088
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
Seattle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6376 entries, 0 to 6375
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6376 non-null   int64
#  1   name                            6376 non-null   object
#  2   host_id                         6376 non-null   int64
#  3   host_name                       6376 non-null   object
#  4   neighbourhood_group             6376 non-null   object
#  5   neighbourhood                   6376 non-null   object
#  6   latitude                        6376 non-null   float64
#  7   longitude                       6376 non-null   float64
#  8   room_type                       6376 non-null   object
#  9   price                           6376 non-null   int64
#  10  minimum_nights                  6376 non-null   int64
#  11  number_of_reviews               6376 non-null   int64
# ...

# %%
Seattle_data.head()
# Out:
#        id                                              name  host_id  \
# 0  879181                  In Jimi Hendrix's neighborhood 3   287172
# 1    6606               Fab, private seattle urban cottage!    14942
# 2  902609                Entire guest suite in West Seattle  3264544
# 3    9419               Glorious sun room w/ memory foambed    30559
# 4  226536  Serene Room in Sunny Cottage near Discovery Park   209571
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0      Laura         Central Area       Atlantic  47.60096 -122.30190
# 1      Joyce  Other neighborhoods    Wallingford  47.65444 -122.33629
# 2      Fabio             Delridge  Highland Park  47.52383 -122.35287
# 3  Angielena  Other neighborhoods     Georgetown  47.55017 -122.31937
# 4     Cheryl             Magnolia    Lawton Park  47.66133 -122.40088
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
Seattle_data.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1087
# reviews_per_month                 1087
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1459
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='room_type', y='price', data=Seattle_data)

plt.xlabel("Room Type", size=13)
plt.ylabel("Price", size=13)
plt.title("Room Type vs Price",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Room Type vs Price')

# %% [markdown]
# We can know that there are four room types: private room, entire home/apt, shared room and hotel room. The hotel room price is always lower than others. On the other hand, the entire room have the highest price amoung these four types of rooms and varies remarkably.

# %% [markdown]
# Below graph shows details about price and room type based on neighborhood group. The highest price of these four room types is always in the same area which is Downtown. This makes sense because the house price in douwntown is always higher than other regions.

# %%
plt.figure(figsize=(15,12))
sns.scatterplot(x="room_type", y="price",
            hue="neighbourhood_group", size="neighbourhood_group",
            sizes=(50, 200), palette="Dark2", data=Seattle_data)

plt.xlabel("Room Type", size=13)
plt.ylabel("Price", size=13)
plt.title("Room Type vs Price vs Neighbourhood Group",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Room Type vs Price vs Neighbourhood Group')

# %% [markdown]
# Another graph is about price vs number of reviews based on neighborhood group. It shows us the lowest prices have higher reviews than the higher prices. It shows negative correlation between price and number of reviews. But it is worth mentioning that there also exist some fluactuate, which may be caused by factors such as holidays. From this graph we can know that number of reviews in west Seattle and Beacon hill is higher than that of in other regions.

# %%
plt.figure(figsize=(15,12))
sns.set_palette("Set1")

sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Central Area'],
             label='Central Area')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Other neighborhoods'],
             label='Other neighborhoods')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Delridge'],
             label='Queens')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Chapitol Hill'],
             label='Staten Island')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Magnolia'],
             label='Magnolia')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Beacon Hill'],
             label='Beacon Hill')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='West Seattle'],
             label='West Seattle')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Ballard'],
             label='Ballard')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Queen Anne'],
             label='Queen Anne')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Downtown'],
             label='Downtown')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Cascade'],
             label='Cascade')
sns.lineplot(x='price', y='number_of_reviews', 
             data=Seattle_data[Seattle_data['neighbourhood_group']=='Rainier Valley'],
             label='Rainier Valley')
plt.xlabel("Price", size=13)
plt.ylabel("Number of Reviews", size=13)
plt.title("Price vs Number of Reviews vs Neighbourhood Group",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Price vs Number of Reviews vs Neighbourhood Group')

# %% [markdown]
# We can also explore the minimum price, maximum price, average price and the median price per listing.

# %%
min_price = Seattle_data['price'].min()
max_price = Seattle_data['price'].max()
mean_price = Seattle_data['price'].mean()
median_price = Seattle_data['price'].median()

print('Minimum price per listing is %d$.' % (min_price))
print('Maximum price per listing is %d$' % (max_price))
print('Average price per listing is %d$.' % (mean_price))
print('Median price per listing is %d$.' % (median_price))
# Out:
# Minimum price per listing is 0$.
# Maximum price per listing is 4000$
# Average price per listing is 161$.
# Median price per listing is 130$.

# %% [markdown]
# Before examining price feature, categorical variables will be mapped with help of cat.code. This will assist to make easier and comprehensible data analysis.

# %%
Seattle_data['neighbourhood_group']= Seattle_data['neighbourhood_group'].astype("category").cat.codes
Seattle_data['neighbourhood'] = Seattle_data['neighbourhood'].astype("category").cat.codes
Seattle_data['room_type'] = Seattle_data['room_type'].astype("category").cat.codes
Seattle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6376 entries, 0 to 6375
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6376 non-null   int64
#  1   name                            6376 non-null   object
#  2   host_id                         6376 non-null   int64
#  3   host_name                       6376 non-null   object
#  4   neighbourhood_group             6376 non-null   int8
#  5   neighbourhood                   6376 non-null   int8
#  6   latitude                        6376 non-null   float64
#  7   longitude                       6376 non-null   float64
#  8   room_type                       6376 non-null   int8
#  9   price                           6376 non-null   int64
#  10  minimum_nights                  6376 non-null   int64
#  11  number_of_reviews               6376 non-null   int64
# ...

# %%
plt.figure(figsize=(10,8))
sns.distplot(Seattle_data['price'], fit=norm)
plt.title("Price Distribution Plot",size=15, weight='bold')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Price Distribution Plot')

# %% [markdown]
# The above distribution graph shows that there is a right-skewed distribution on price. This means there is a positive skewness. Log transformation will be used to make this feature less skewed. This will help to make easier interpretation and better statistical analysis
#
# Since division by zero is a problem, log+1 transformation would be better.

# %%
Seattle_data['price_log'] = np.log(Seattle_data.price+1)

# %% [markdown]
# With help of log transformation, now, price feature have normal distribution.

# %%
plt.figure(figsize=(10,8))
sns.distplot(Seattle_data['price_log'], fit=norm)
plt.title("Log-Price Distribution Plot",size=15, weight='bold')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Log-Price Distribution Plot')

# %% [markdown]
# In below graph, the good fit indicates that normality is a reasonable approximation.

# %%
plt.figure(figsize=(7,7))
stats.probplot(Seattle_data['price_log'], plot=plt)
plt.show()

# %% [markdown]
# ## Data processing

# %% [markdown]
# Number of reviews feature and license feature has some missing data. For the feature reviews_per_month, missing data will be replaced with mean. Since the data is more symmetric, mean replacement would be better.As for liscence, we choose to drop it directly cause the missing proportion is over 20%, which is not suitable for filling.

# %%
#find percentage of missing values for each column
listings_missing_df = Seattle_data.isnull().mean()*100

#filter out only columns, which have missing values
listings_columns_with_nan = listings_missing_df[listings_missing_df > 0]

#plot the results
listings_columns_with_nan.plot.bar(title='Missing values per column, %')
# Out:
# <AxesSubplot:title={'center':'Missing values per column, %'}>

# %% [markdown]
# Now it is time to prepare data for modeling. First, non-nominal data and old price feature will be eliminated.

# %%
seattle_model = Seattle_data.drop(columns=['name','id' ,'host_id','host_name', 
                                   'last_review','price'])
seattle_model.isnull().sum()
# Out:
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                 1087
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1459
# price_log                            0
# dtype: int64

# %%
mean = seattle_model['reviews_per_month'].mean()
seattle_model['reviews_per_month'].fillna(mean, inplace=True)
seattle_model.drop(columns=['license'], inplace=True)
seattle_model.isnull().sum()
# Out:
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# price_log                         0
# dtype: int64

# %% [markdown]
# A correlation table will be created and the Pearson method will be used.

# %%
plt.figure(figsize=(10,8))
palette = sns.diverging_palette(20, 220, n=256)
corr=seattle_model.corr(method='pearson')
sns.heatmap(corr, annot=True, fmt=".2f", cmap=palette, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}).set(ylim=(12, 0))
plt.title("Correlation Matrix",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# The correlation table shows that there is no strong relationship between price and other features. This indicates no feature needed to be taken out of data. This relationship will be detailed with Residual Plots and Multicollinearity.

# %% [markdown]
# ### Residual Plots
# Detect outliers, non-linear data and detecting data for regression models

# %%
seattle_model_x, seattle_model_y = seattle_model.iloc[:,:-1], seattle_model.iloc[:,-1]

# %%
f, axes = plt.subplots(5, 2, figsize=(15, 20))
sns.residplot(seattle_model_x.iloc[:,0],seattle_model_y, lowess=True, ax=axes[0, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,1],seattle_model_y, lowess=True, ax=axes[0, 1],
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,2],seattle_model_y, lowess=True, ax=axes[1, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,3],seattle_model_y, lowess=True, ax=axes[1, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,4],seattle_model_y, lowess=True, ax=axes[2, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,5],seattle_model_y, lowess=True, ax=axes[2, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,6],seattle_model_y, lowess=True, ax=axes[3, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,7],seattle_model_y, lowess=True, ax=axes[3, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,8],seattle_model_y, lowess=True, ax=axes[4, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(seattle_model_x.iloc[:,9],seattle_model_y, lowess=True, ax=axes[4, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
plt.setp(axes, yticks=[])
plt.tight_layout()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Multicollinearity
# Multicollinearity will help to measure the relationship between explanatory variables in multiple regression. If there is multicollinearity occurs, these highly related input variables should be eliminated from the model.
#
# In this kernel, multicollinearity will be control with Eigen vector values results.

# %%
#Eigen vector of a correlation matrix.
multicollinearity, V=np.linalg.eig(corr)
multicollinearity
# Out:
# array([2.64076128, 1.55239721, 0.1834325 , 1.31088944, 0.45364114,
#        0.48242467, 0.63521911, 0.70487965, 0.87358917, 0.94712272,
#        1.0789103 , 1.13673279])

# %% [markdown]
# None one of the eigenvalues of the correlation matrix is close to zero. It means that there is no multicollinearity exists in the data.

# %% [markdown]
# ### Feature Selection and GridSearch
# First, Standard Scaler technique will be used to normalize the data set. Thus, each feature has 0 mean and 1 standard deviation.

# %%
seattle_model_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6376 entries, 0 to 6375
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             6376 non-null   int8
#  1   neighbourhood                   6376 non-null   int8
#  2   latitude                        6376 non-null   float64
#  3   longitude                       6376 non-null   float64
#  4   room_type                       6376 non-null   int8
#  5   minimum_nights                  6376 non-null   int64
#  6   number_of_reviews               6376 non-null   int64
#  7   reviews_per_month               6376 non-null   float64
#  8   calculated_host_listings_count  6376 non-null   int64
#  9   availability_365                6376 non-null   int64
#  10  number_of_reviews_ltm           6376 non-null   int64
# dtypes: float64(3), int64(5), int8(3)
# memory usage: 417.3 KB

# %%
scaler = StandardScaler()
seattle_model_x = scaler.fit_transform(seattle_model_x)

# %%
X_train, X_test, y_train, y_test = train_test_split(seattle_model_x, seattle_model_y, test_size=0.3,random_state=42)

# %%
lab_enc = preprocessing.LabelEncoder()

feature_model = ExtraTreesClassifier(n_estimators=50)
feature_model.fit(X_train,lab_enc.fit_transform(y_train))

plt.figure(figsize=(7,7))
feat_importances = pd.Series(feature_model.feature_importances_, index=seattle_model.iloc[:,:-1].columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# The above graph shows the feature importance of dataset. According to that, neighborhood group has the lowest importance on the model. Under this result, the model building will be made in 2 phases. In the first phase, models will be built within all features and in the second phase, models will be built without neighborhood group feature.

# %% [markdown]
# ## Regression analysis（model building)
# ### Phase 1 - With All Features
# Correlation matrix, Residual Plots and Multicollinearity results show that underfitting occurs on the model and there is no multicollinearity on the independent variables. Avoiding underfitting will be made with Polynomial Transformation since no new features can not be added or replaced with the existing ones.
#
# In model building section, Linear Regression, Ridge Regression, Lasso Regression, and ElasticNet Regression models will be built. These models will be used to avoiding plain Linear Regression and show the results with a little of regularization.
#
# First, GridSearchCV algorithm will be used to find the best parameters and tuning hyperparameters for each model. In this algorithm 5-Fold Cross Validation and Mean Squared Error Regression Loss metrics will be used.

# %%
linear_reg(seattle_model_x, seattle_model_y)

ridge_reg(seattle_model_x, seattle_model_y)

lasso_reg(seattle_model_x, seattle_model_y)

elastic_reg(seattle_model_x, seattle_model_y)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# -0.25442774940756774
# {'alpha': 0.1, 'normalize': True}
# -0.2536124599724391
# {'alpha': 0.01, 'normalize': False}
# -0.2538124386906325
# {'alpha': 0.01, 'normalize': False}
# -0.2534940322303025

# %% [markdown]
# #### K-Fold Cross Validation
#
# Before model building, 5-Fold Cross Validation will be implemented for validation.

# %%
kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
for train_index, test_index in kfold_cv.split(seattle_model_x, seattle_model_y):
    X_train, X_test = seattle_model_x[train_index], seattle_model_x[test_index]
    y_train, y_test = seattle_model_y[train_index], seattle_model_y[test_index]

# %% [markdown]
# #### Polynomial Transformation
# The polynomial transformation will be made with a second degree which adding the square of each feature.

# %%
Poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_train = Poly.fit_transform(X_train)
X_test = Poly.fit_transform(X_test)

# %% [markdown]
# #### Model Prediction

# %%
##Linear Regression
lr = LinearRegression(copy_X= True, fit_intercept = True, normalize = True)
lr.fit(X_train, y_train)
lr_pred= lr.predict(X_test)

#Ridge Model
ridge_model = Ridge(alpha = 0.001, normalize = True)
ridge_model.fit(X_train, y_train)             
pred_ridge = ridge_model.predict(X_test) 

#Lasso Model
Lasso_model = Lasso(alpha = 0.001, normalize =False)
Lasso_model.fit(X_train, y_train)
pred_Lasso = Lasso_model.predict(X_test) 

#ElasticNet Model
model_enet = ElasticNet(alpha = 0.01, normalize=False)
model_enet.fit(X_train, y_train) 
pred_test_enet= model_enet.predict(X_test)

# %% [markdown]
# ### Phase 2 - Without unsignificant Features
#
# All steps from Phase 1, will be repeated in this Phase. The difference is, ``neighbourhood_group`` feature will be eliminated.

# %%
seattle_model_xx= seattle_model.drop(columns=['neighbourhood_group'])

# %%
seattle_model_xx, seattle_model_yx = seattle_model_xx.iloc[:,:-1], seattle_model_xx.iloc[:,-1]
X_train_x, X_test_x, y_train_x, y_test_x = train_test_split(seattle_model_xx, seattle_model_yx, test_size=0.1,random_state=42)

# %%
scaler = StandardScaler()
seattle_model_xx = scaler.fit_transform(seattle_model_xx)

# %%
### Linear Regression ###
linear_reg(seattle_model_xx, seattle_model_yx, cv=4)
### Ridge Regression ###
ridge_reg(seattle_model_xx, seattle_model_yx, cv=4)
### Lasso Regression ###
lasso_reg(seattle_model_xx, seattle_model_yx, cv=4)
### ElasticNet Regression ###
elastic_reg(seattle_model_xx, seattle_model_yx, cv=4)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': False}
# -0.25784367445385237
# {'alpha': 0.1, 'normalize': True}
# -0.25608028429935004
# {'alpha': 0.01, 'normalize': False}
# -0.2551822890166622
# {'alpha': 0.01, 'normalize': False}
# -0.25532214330051484

# %% [markdown]
# #### K-Fold Cross Validation
# Before model building, 5-Fold Cross Validation will be implemented for validation.

# %%
kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
for train_index, test_index in kfold_cv.split(seattle_model_xx,seattle_model_yx):
    X_train_x, X_test_x = seattle_model_xx[train_index], seattle_model_xx[test_index]
    y_train_x, y_test_x = seattle_model_yx[train_index], seattle_model_yx[test_index]

# %% [markdown]
# #### Polynomial Transformation
# The polynomial transformation will be made with a second degree which adding the square of each feature.

# %%
Poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_train_x = Poly.fit_transform(X_train_x)
X_test_x = Poly.fit_transform(X_test_x)

# %% [markdown]
# #### Model Prediction

# %%
###Linear Regression
lr_x = LinearRegression(copy_X= True, fit_intercept = True, normalize = True)
lr_x.fit(X_train_x, y_train_x)
lr_pred_x= lr_x.predict(X_test_x)

###Ridge
ridge_x = Ridge(alpha = 0.008, normalize = True)
ridge_x.fit(X_train_x, y_train_x)           
pred_ridge_x = ridge_x.predict(X_test_x) 

###Lasso
Lasso_x = Lasso(alpha = 0.001, normalize =False)
Lasso_x.fit(X_train_x, y_train_x)
pred_Lasso_x = Lasso_x.predict(X_test_x) 

##ElasticNet
model_enet_x = ElasticNet(alpha = 0.01, normalize=False)
model_enet_x.fit(X_train_x, y_train_x) 
pred_train_enet_x= model_enet_x.predict(X_train_x)
pred_test_enet_x= model_enet_x.predict(X_test_x)

# %% [markdown]
# ## Model evaluation and testing
#
# In this part, 3 metrics will be calculated for evaluating predictions.
#
# * ``Mean Absolute Error (MAE)``    shows the difference between predictions and actual values.
#
# * ``Root Mean Square Error (RMSE)`` shows how accurately the model predicts the response.
#
# *                   ``R^2``  will be calculated to find the goodness of fit measure.

# %%
print('-------------Linear Regression-----------')

print('--Phase-1--')
print('MAE: %f'% mean_absolute_error(y_test, lr_pred))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test, lr_pred)))   
print('R2 %f' % r2_score(y_test, lr_pred))

print('--Phase-2--')
print('MAE: %f'% mean_absolute_error(y_test_x, lr_pred_x))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test_x, lr_pred_x)))   
print('R2 %f' % r2_score(y_test_x, lr_pred_x))

print('---------------Ridge ---------------------')

print('--Phase-1--')
print('MAE: %f'% mean_absolute_error(y_test, pred_ridge))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test, pred_ridge)))   
print('R2 %f' % r2_score(y_test, pred_ridge))

print('--Phase-2--')
print('MAE: %f'% mean_absolute_error(y_test_x, pred_ridge_x))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test_x, pred_ridge_x)))   
print('R2 %f' % r2_score(y_test_x, pred_ridge_x))

print('---------------Lasso-----------------------')

print('--Phase-1--')
print('MAE: %f' % mean_absolute_error(y_test, pred_Lasso))
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test, pred_Lasso)))
print('R2 %f' % r2_score(y_test, pred_Lasso))

print('--Phase-2--')
print('MAE: %f' % mean_absolute_error(y_test_x, pred_Lasso_x))
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test_x, pred_Lasso_x)))
print('R2 %f' % r2_score(y_test_x, pred_Lasso_x))

print('---------------ElasticNet-------------------')

print('--Phase-1 --')
print('MAE: %f' % mean_absolute_error(y_test,pred_test_enet)) #RMSE
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test,pred_test_enet))) #RMSE
print('R2 %f' % r2_score(y_test, pred_test_enet))

print('--Phase-2--')
print('MAE: %f' % mean_absolute_error(y_test_x,pred_test_enet_x)) #RMSE
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test_x,pred_test_enet_x))) #RMSE
print('R2 %f' % r2_score(y_test_x, pred_test_enet_x))
# Out:
# -------------Linear Regression-----------
# --Phase-1--
# MAE: 0.372638
# RMSE: 0.487737
# R2 0.304068
# --Phase-2--
# MAE: 0.376202
# RMSE: 0.491634
# R2 0.292901
# ---------------Ridge ---------------------
# --Phase-1--
# MAE: 0.372684
# RMSE: 0.487771
# R2 0.303970
# --Phase-2--
# MAE: 0.376571
# RMSE: 0.491895
# R2 0.292150
# ---------------Lasso-----------------------
# --Phase-1--
# MAE: 0.372654
# RMSE: 0.487610
# R2 0.304430
# --Phase-2--
# MAE: 0.376291
# RMSE: 0.491583
# R2 0.293049
# ---------------ElasticNet-------------------
# --Phase-1 --
# MAE: 0.375419
# RMSE: 0.491731
# R2 0.292623
# --Phase-2--
# MAE: 0.377153
# RMSE: 0.493662
# R2 0.287055

# %% [markdown]
# The results show that all models have similar prediction results. Phase 1 and 2 have a great difference for each metric. All metric values are increased in Phase 2 it means, the prediction error value is higher in that Phase and model explainability are very low the variability of the response data around mean.
#
# * The MAE value of 0 indicates no error on the model. In other words, there is a perfect prediction. The above results show that all predictions have great error especially in phase 2.
# * RMSE gives an idea of how much error the system typically makes in its predictions. The above results show that all models with each phase have significant errors.
# * The R2 (Coefficient of Determination) values in phase 1 range from approximately 0.2926 to 0.3044, indicating the proportion of the variance in the dependent variable explained by the independent variables, while the values in phase 2 range from approximately 0.2866 to 0.2925. Higher values indicate a better fit.

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4, figsize=(30, 20))
fig.suptitle('True Values vs Predictions')

ax1.scatter(y_test, lr_pred)
ax1.set_title('Linear Regression - Phase-1')

ax2.scatter(y_test, pred_ridge)
ax2.set_title('Ridge - Phase-1')

ax3.scatter(y_test, pred_Lasso)
ax3.set_title('Lasso - Phase-1')

ax4.scatter(y_test, pred_test_enet)
ax4.set_title('ElasticNet - Phase-1')

ax5.scatter(y_test_x, lr_pred_x)
ax5.set_title('Linear Regression - Phase-2')

ax6.scatter(y_test_x, pred_ridge_x)
ax6.set_title('Ridge - Phase-2')

ax7.scatter(y_test_x, pred_Lasso_x)
ax7.set_title('Lasso - Phase-2')

ax8.scatter(y_test_x, pred_test_enet_x)
ax8.set_title('ElasticNet - Phase-2')

for ax in fig.get_axes():
    ax.set(xlabel='True Values', ylabel='Predictions')

# %% [markdown]
# The last graph is about the difference between True Values vs Prediction for Phase 1 and Phase 2. The great difference between the two phases has been seen in four models.

# %% [markdown]
# # Nashville

# %% [markdown]
# ## Extraction of AirBnB datasets (Nashville)

# %%
nashville_data = pd.read_csv('./data/Task2/AirBnB_Nashville.csv')
nashville_data.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               8548
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1188
# reviews_per_month                 1188
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           8548
# dtype: int64

# %%
nashville_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8548 entries, 0 to 8547
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8548 non-null   int64
#  1   name                            8548 non-null   object
#  2   host_id                         8548 non-null   int64
#  3   host_name                       8548 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   8548 non-null   object
#  6   latitude                        8548 non-null   float64
#  7   longitude                       8548 non-null   float64
#  8   room_type                       8548 non-null   object
#  9   price                           8548 non-null   int64
#  10  minimum_nights                  8548 non-null   int64
#  11  number_of_reviews               8548 non-null   int64
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='room_type', y='price', data=nashville_data)

plt.xlabel("Room Type", size=13)
plt.ylabel("Price", size=13)
plt.title("Room Type vs Price",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Room Type vs Price')

# %% [markdown]
# We can know that there are four room types: private room, entire home/apt, shared room and hotel room. The shared room price is the lowest amoung these four room types and it concentrates on a relatively low level of price. On the other hand, the entire room have the highest price amoung these four types of rooms.

# %% [markdown]
# Due to the missing value for feature 'neighbourhood_group' is high, we cannot visualize the room type vs price vs neighbourhood group as before.

# %% [markdown]
# We can also explore the minimum price, maximum price, average price and the median price per listing.

# %%
min_price = nashville_data['price'].min()
max_price = nashville_data['price'].max()
mean_price = nashville_data['price'].mean()
median_price = nashville_data['price'].median()

print('Minimum price per listing is %d$.' % (min_price))
print('Maximum price per listing is %d$' % (max_price))
print('Average price per listing is %d$.' % (mean_price))
print('Median price per listing is %d$.' % (median_price))
# Out:
# Minimum price per listing is 0$.
# Maximum price per listing is 78200$
# Average price per listing is 281$.
# Median price per listing is 198$.

# %% [markdown]
# Before examining price feature, categorical variables will be mapped with help of cat.code. This will assist to make easier and comprehensible data analysis.

# %%
nashville_data['neighbourhood'] = nashville_data['neighbourhood'].astype("category").cat.codes
nashville_data['room_type'] = nashville_data['room_type'].astype("category").cat.codes
nashville_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8548 entries, 0 to 8547
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8548 non-null   int64
#  1   name                            8548 non-null   object
#  2   host_id                         8548 non-null   int64
#  3   host_name                       8548 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   8548 non-null   int8
#  6   latitude                        8548 non-null   float64
#  7   longitude                       8548 non-null   float64
#  8   room_type                       8548 non-null   int8
#  9   price                           8548 non-null   int64
#  10  minimum_nights                  8548 non-null   int64
#  11  number_of_reviews               8548 non-null   int64
# ...

# %%
plt.figure(figsize=(10,10))
sns.distplot(nashville_data['price'], fit=norm)
plt.title("Price Distribution Plot",size=15, weight='bold')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Price Distribution Plot')

# %% [markdown]
# The above distribution graph shows that there is a right-skewed distribution on price. This means there is a positive skewness. Log transformation will be used to make this feature less skewed. This will help to make easier interpretation and better statistical analysis
#
# Since division by zero is a problem, log+1 transformation would be better.

# %%
nashville_data['price_log'] = np.log(nashville_data.price+1)

# %% [markdown]
# With help of log transformation, now, price feature have normal distribution.

# %%
plt.figure(figsize=(12,10))
sns.distplot(nashville_data['price_log'], fit=norm)
plt.title("Log-Price Distribution Plot",size=15, weight='bold')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Log-Price Distribution Plot')

# %% [markdown]
# In below graph, the good fit indicates that normality is a reasonable approximation.

# %%
plt.figure(figsize=(7,7))
stats.probplot(nashville_data['price_log'], plot=plt)
plt.show()

# %% [markdown]
# ## Data processing

# %% [markdown]
# Now it is time to prepare data for modeling. First, non-nominal data and old price feature will be eliminated.

# %%
nashville_model = nashville_data.drop(columns=['name','id' ,'host_id','host_name', 
                                   'last_review','price'])
nashville_model.isnull().sum()
# Out:
# neighbourhood_group               8548
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                 1188
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           8548
# price_log                            0
# dtype: int64

# %%
#find percentage of missing values for each column
nashville_missing_data = nashville_data.isnull().mean()*100

#filter out only columns, which have missing values
nashville_missing_data = nashville_missing_data[nashville_missing_data > 0]

#plot the results
nashville_missing_data.plot.bar(title='Missing values per column, %')
# Out:
# <AxesSubplot:title={'center':'Missing values per column, %'}>

# %% [markdown]
# Number of reviews feature and license feature has some missing data. For the feature reviews_per_month, missing data will be replaced with mean. Since the data is more symmetric, mean replacement would be better. As for liscence and neighbourhood_group, we choose to drop them directly cause the missing proportion is too much.

# %%
mean = nashville_model['reviews_per_month'].mean()
nashville_model['reviews_per_month'].fillna(mean, inplace=True)
nashville_model.drop(columns = ['license','neighbourhood_group'], inplace=True)
nashville_model.isnull().sum()
# Out:
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# price_log                         0
# dtype: int64

# %% [markdown]
# A correlation table will be created and the Pearson method will be used.

# %%
plt.figure(figsize=(10, 8))
palette = sns.diverging_palette(20, 220, n=256)
corr = nashville_model.corr(method='pearson')
sns.heatmap(corr, annot=True, fmt=".2f", cmap=palette, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.ylim(11, 0)
plt.title("Correlation Matrix", size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# The correlation table shows that there is no strong relationship between price and other features. This indicates no feature needed to be taken out of data. This relationship will be detailed with Residual Plots and Multicollinearity.

# %% [markdown]
# ### Residual Plots
# Detect outliers, non-linear data and detecting data for regression models

# %%
nashville_model_x, nashville_model_y = nashville_model.iloc[:,:-1], nashville_model.iloc[:,-1]

# %%
f, axes = plt.subplots(5, 2, figsize=(15, 20))
sns.residplot(nashville_model_x.iloc[:,0],nashville_model_y, lowess=True, ax=axes[0, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,1],nashville_model_y, lowess=True, ax=axes[0, 1],
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,2],nashville_model_y, lowess=True, ax=axes[1, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,3],nashville_model_y, lowess=True, ax=axes[1, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,4],nashville_model_y, lowess=True, ax=axes[2, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,5],nashville_model_y, lowess=True, ax=axes[2, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,6],nashville_model_y, lowess=True, ax=axes[3, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,7],nashville_model_y, lowess=True, ax=axes[3, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,8],nashville_model_y, lowess=True, ax=axes[4, 0], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
sns.residplot(nashville_model_x.iloc[:,9],nashville_model_y, lowess=True, ax=axes[4, 1], 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
plt.setp(axes, yticks=[])
plt.tight_layout()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Multicollinearity
# Multicollinearity will help to measure the relationship between explanatory variables in multiple regression. If there is multicollinearity occurs, these highly related input variables should be eliminated from the model.
#
# In this kernel, multicollinearity will be control with Eigen vector values results.

# %%
#Eigen vector of a correlation matrix.
multicollinearity, V=np.linalg.eig(corr)
multicollinearity
# Out:
# array([2.46109889, 1.70575611, 0.12459028, 1.23943966, 0.44973015,
#        0.62343005, 1.03071482, 1.00477093, 0.75091175, 0.81027896,
#        0.79927841])

# %% [markdown]
# None one of the eigenvalues of the correlation matrix is close to zero. It means that there is no multicollinearity exists in the data.

# %% [markdown]
# ### Feature Selection and GridSearch
# First, Standard Scaler technique will be used to normalize the data set. Thus, each feature has 0 mean and 1 standard deviation.

# %%
nashville_model_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8548 entries, 0 to 8547
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood                   8548 non-null   int8
#  1   latitude                        8548 non-null   float64
#  2   longitude                       8548 non-null   float64
#  3   room_type                       8548 non-null   int8
#  4   minimum_nights                  8548 non-null   int64
#  5   number_of_reviews               8548 non-null   int64
#  6   reviews_per_month               8548 non-null   float64
#  7   calculated_host_listings_count  8548 non-null   int64
#  8   availability_365                8548 non-null   int64
#  9   number_of_reviews_ltm           8548 non-null   int64
# dtypes: float64(3), int64(5), int8(2)
# memory usage: 551.1 KB

# %%
scaler = StandardScaler()
nashville_model_x = scaler.fit_transform(nashville_model_x)

# %%
X_train, X_test, y_train, y_test = train_test_split(nashville_model_x, nashville_model_y, test_size=0.15,random_state=42)

# %%
lab_enc = preprocessing.LabelEncoder()

feature_model = ExtraTreesClassifier(n_estimators=50)
feature_model.fit(X_train,lab_enc.fit_transform(y_train))

plt.figure(figsize=(7,7))
feat_importances = pd.Series(feature_model.feature_importances_, index=nashville_model.iloc[:,:-1].columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# The above graph shows the feature importance of dataset. According to that, room type has the lowest importance on the model. Under this result, the model building will be made in 2 phases. In the first phase, models will be built within all features and in the second phase, models will be built without room type feature.

# %% [markdown]
# ## Regression analysis (model building)
# ### Phase 1 - With All Features
# Correlation matrix, Residual Plots and Multicollinearity results show that underfitting occurs on the model and there is no multicollinearity on the independent variables. Avoiding underfitting will be made with Polynomial Transformation since no new features can not be added or replaced with the existing ones.
#
# In model building section, Linear Regression, Ridge Regression, Lasso Regression, and ElasticNet Regression models will be built. These models will be used to avoiding plain Linear Regression and show the results with a little of regularization.
#
# First, GridSearchCV algorithm will be used to find the best parameters and tuning hyperparameters for each model. In this algorithm 5-Fold Cross Validation and Mean Squared Error Regression Loss metrics will be used.

# %%
linear_reg(nashville_model_x, nashville_model_y)

ridge_reg(nashville_model_x, nashville_model_y)

lasso_reg(nashville_model_x, nashville_model_y)

elastic_reg(nashville_model_x, nashville_model_y)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': False}
# -0.518143504623805
# {'alpha': 1.0, 'normalize': True}
# -0.47405466036351773
# {'alpha': 0.1, 'normalize': False}
# -0.48878758327423233
# {'alpha': 0.1, 'normalize': False}
# -0.4736213282459465

# %% [markdown]
# #### K-Fold Cross Validation
#
# Before model building, 5-Fold Cross Validation will be implemented for validation.

# %%
kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
for train_index, test_index in kfold_cv.split(nashville_model_x, nashville_model_y):
    X_train, X_test = nashville_model_x[train_index], nashville_model_x[test_index]
    y_train, y_test = nashville_model_y[train_index], nashville_model_y[test_index]

# %% [markdown]
# #### Polynomial Transformation
# The polynomial transformation will be made with a second degree which adding the square of each feature.

# %%
Poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_train = Poly.fit_transform(X_train)
X_test = Poly.fit_transform(X_test)

# %% [markdown]
# #### Model Prediction

# %%
##Linear Regression
lr = LinearRegression(copy_X= True, fit_intercept = True, normalize = True)
lr.fit(X_train, y_train)
lr_pred= lr.predict(X_test)

#Ridge Model
ridge_model = Ridge(alpha = 0.008, normalize = True)
ridge_model.fit(X_train, y_train)             
pred_ridge = ridge_model.predict(X_test) 

#Lasso Model
Lasso_model = Lasso(alpha = 0.001, normalize =False)
Lasso_model.fit(X_train, y_train)
pred_Lasso = Lasso_model.predict(X_test) 

#ElasticNet Model
model_enet = ElasticNet(alpha = 0.01, normalize=False)
model_enet.fit(X_train, y_train) 
pred_test_enet= model_enet.predict(X_test)

# %% [markdown]
# ### Phase 2 - Without unsignificant Features
#
# All steps from Phase 1, will be repeated in this Phase. The difference is, ``room_type`` features will be eliminated.

# %%
nashville_model_xx= nashville_model.drop(columns=['room_type'])

# %%
nashville_model_xx, nashville_model_yx = nashville_model_xx.iloc[:,:-1], nashville_model_xx.iloc[:,-1]
X_train_x, X_test_x, y_train_x, y_test_x = train_test_split(nashville_model_xx, nashville_model_yx, test_size=0.15,random_state=42)

# %%
scaler = StandardScaler()
nashville_model_xx = scaler.fit_transform(nashville_model_xx)

# %%
### Linear Regression ###
linear_reg(nashville_model_xx, nashville_model_yx, cv=4)
### Ridge Regression ###
ridge_reg(nashville_model_xx, nashville_model_yx, cv=4)
### Lasso Regression ###
lasso_reg(nashville_model_xx, nashville_model_yx, cv=4)
### ElasticNet Regression ###
elastic_reg(nashville_model_xx, nashville_model_yx, cv=4)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# -0.6011233787529782
# {'alpha': 1.0, 'normalize': True}
# -0.5164148496536598
# {'alpha': 0.1, 'normalize': False}
# -0.5147186690638507
# {'alpha': 0.001, 'normalize': True}
# -0.5162481376767871

# %% [markdown]
# #### K-Fold Cross Validation

# %%
kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
for train_index, test_index in kfold_cv.split(nashville_model_xx,nashville_model_yx):
    X_train_x, X_test_x = nashville_model_xx[train_index], nashville_model_xx[test_index]
    y_train_x, y_test_x = nashville_model_yx[train_index], nashville_model_yx[test_index]

# %% [markdown]
# #### Polynomial Transformation

# %%
Poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_train_x = Poly.fit_transform(X_train_x)
X_test_x = Poly.fit_transform(X_test_x)

# %% [markdown]
# #### Model Prediction

# %%
###Linear Regression
lr_x = LinearRegression(copy_X= True, fit_intercept = True, normalize = True)
lr_x.fit(X_train_x, y_train_x)
lr_pred_x= lr_x.predict(X_test_x)

###Ridge
ridge_x = Ridge(alpha = 0.008, normalize = True)
ridge_x.fit(X_train_x, y_train_x)           
pred_ridge_x = ridge_x.predict(X_test_x) 

###Lasso
Lasso_x = Lasso(alpha = 0.001, normalize =False)
Lasso_x.fit(X_train_x, y_train_x)
pred_Lasso_x = Lasso_x.predict(X_test_x) 

##ElasticNet
model_enet_x = ElasticNet(alpha = 0.01, normalize=False)
model_enet_x.fit(X_train_x, y_train_x) 
pred_train_enet_x= model_enet_x.predict(X_train_x)
pred_test_enet_x= model_enet_x.predict(X_test_x)

# %% [markdown]
# ## Model evaluation and testing
#
# In this part, 3 metrics will be calculated for evaluating predictions.
#
# * ``Mean Absolute Error (MAE)``    shows the difference between predictions and actual values.
#
# * ``Root Mean Square Error (RMSE)`` shows how accurately the model predicts the response.
#
# *                   ``R^2``  will be calculated to find the goodness of fit measure.

# %%
print('-------------Linear Regression-----------')

print('--Phase-1--')
print('MAE: %f'% mean_absolute_error(y_test, lr_pred))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test, lr_pred)))   
print('R2 %f' % r2_score(y_test, lr_pred))

print('--Phase-2--')
print('MAE: %f'% mean_absolute_error(y_test_x, lr_pred_x))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test_x, lr_pred_x)))   
print('R2 %f' % r2_score(y_test_x, lr_pred_x))

print('---------------Ridge ---------------------')

print('--Phase-1--')
print('MAE: %f'% mean_absolute_error(y_test, pred_ridge))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test, pred_ridge)))   
print('R2 %f' % r2_score(y_test, pred_ridge))

print('--Phase-2--')
print('MAE: %f'% mean_absolute_error(y_test_x, pred_ridge_x))
print('RMSE: %f'% np.sqrt(mean_squared_error(y_test_x, pred_ridge_x)))   
print('R2 %f' % r2_score(y_test_x, pred_ridge_x))

print('---------------Lasso-----------------------')

print('--Phase-1--')
print('MAE: %f' % mean_absolute_error(y_test, pred_Lasso))
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test, pred_Lasso)))
print('R2 %f' % r2_score(y_test, pred_Lasso))

print('--Phase-2--')
print('MAE: %f' % mean_absolute_error(y_test_x, pred_Lasso_x))
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test_x, pred_Lasso_x)))
print('R2 %f' % r2_score(y_test_x, pred_Lasso_x))

print('---------------ElasticNet-------------------')

print('--Phase-1 --')
print('MAE: %f' % mean_absolute_error(y_test,pred_test_enet)) #RMSE
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test,pred_test_enet))) #RMSE
print('R2 %f' % r2_score(y_test, pred_test_enet))

print('--Phase-2--')
print('MAE: %f' % mean_absolute_error(y_test_x,pred_test_enet_x)) #RMSE
print('RMSE: %f' % np.sqrt(mean_squared_error(y_test_x,pred_test_enet_x))) #RMSE
print('R2 %f' % r2_score(y_test_x, pred_test_enet_x))
# Out:
# -------------Linear Regression-----------
# --Phase-1--
# MAE: 0.483935
# RMSE: 0.686315
# R2 0.114171
# --Phase-2--
# MAE: 0.504314
# RMSE: 0.676002
# R2 0.140593
# ---------------Ridge ---------------------
# --Phase-1--
# MAE: 0.483956
# RMSE: 0.681022
# R2 0.127783
# --Phase-2--
# MAE: 0.504188
# RMSE: 0.674929
# R2 0.143319
# ---------------Lasso-----------------------
# --Phase-1--
# MAE: 0.484003
# RMSE: 0.684288
# R2 0.119398
# --Phase-2--
# MAE: 0.504148
# RMSE: 0.675121
# R2 0.142832
# ---------------ElasticNet-------------------
# --Phase-1 --
# MAE: 0.486324
# RMSE: 0.669011
# R2 0.158276
# --Phase-2--
# MAE: 0.506003
# RMSE: 0.675224
# R2 0.142571

# %% [markdown]
# All models, including linear regression, Ridge regression, Lasso regression, and ElasticNet regression, have similar performance in terms of MAE and RMSE.
# * MAE:
# The MAE values range from 0.483983 to 0.504087, indicating the average absolute difference between the predicted and actual values.
# * RMSE:
# The RMSE values range from 0.669011 to 0.697388, representing the typical magnitude of errors made by the models.
# * R2:
# The R2 scores indicate the proportion of variance explained by the models. All models have relatively low R2 values, ranging from 0.085357 to 0.158276, suggesting limited explanatory power.
#
#
# Overall, the models on this dataset seem to have limited performance in predicting the target variable, as indicated by the relatively high MAE and RMSE values and low R2 scores. It is recommended to further analyze the data, consider feature engineering, or explore different modeling techniques to improve the models' predictive accuracy and explainability.

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4, figsize=(30, 20))
fig.suptitle('True Values vs Predictions')

ax1.scatter(y_test, lr_pred)
ax1.set_title('Linear Regression - Phase-1')

ax2.scatter(y_test, pred_ridge)
ax2.set_title('Ridge - Phase-1')

ax3.scatter(y_test, pred_Lasso)
ax3.set_title('Lasso - Phase-1')

ax4.scatter(y_test, pred_test_enet)
ax4.set_title('ElasticNet - Phase-1')

ax5.scatter(y_test_x, lr_pred_x)
ax5.set_title('Linear Regression - Phase-2')

ax6.scatter(y_test_x, pred_ridge_x)
ax6.set_title('Ridge - Phase-2')

ax7.scatter(y_test_x, pred_Lasso_x)
ax7.set_title('Lasso - Phase-2')

ax8.scatter(y_test_x, pred_test_enet_x)
ax8.set_title('ElasticNet - Phase-2')

for ax in fig.get_axes():
    ax.set(xlabel='True Values', ylabel='Predictions')

# %% [markdown]
# The last graph is about the difference between True Values vs Prediction for Phase 1 and Phase 2. The difference between the two phases in these four models are all distinct, while in model 'ElasticNet Regression' is relatively more noticable.

# %% [markdown]
# # Conclusion

# %% [markdown]
# By comparing these three datasets, we can know that the average price and median price per listing in Nashville is the highest, while the highest price exists in NYC.

# %%
nyc_min_price = nyc_data['price'].min()
nyc_max_price = nyc_data['price'].max()
nyc_mean_price = nyc_data['price'].mean()
nyc_median_price = nyc_data['price'].median()

Seattle_min_price = Seattle_data['price'].min()
Seattle_max_price = Seattle_data['price'].max()
Seattle_mean_price = Seattle_data['price'].mean()
Seattle_median_price = Seattle_data['price'].median()

nashville_min_price = nashville_data['price'].min()
nashville_max_price = nashville_data['price'].max()
nashville_mean_price = nashville_data['price'].mean()
nashville_median_price = nashville_data['price'].median()

print("------------ NYC ------------")
print('Minimum price per listing is %d$.' % (nyc_min_price))
print('Maximum price per listing is %d$' % (nyc_max_price))
print('Average price per listing is %d$.' % (nyc_mean_price))
print('Median price per listing is %d$.' % (nyc_median_price))

print("------------ Seattle ------------")
print('Minimum price per listing is %d$.' % (Seattle_min_price))
print('Maximum price per listing is %d$' % (Seattle_max_price))
print('Average price per listing is %d$.' % (Seattle_mean_price))
print('Median price per listing is %d$.' % (Seattle_median_price))

print("------------ Nashville ------------")
print('Minimum price per listing is %d$.' % (nashville_min_price))
print('Maximum price per listing is %d$' % (nashville_max_price))
print('Average price per listing is %d$.' % (nashville_mean_price))
print('Median price per listing is %d$.' % (nashville_median_price))
# Out:
# ------------ NYC ------------
# Minimum price per listing is 0$.
# Maximum price per listing is 99000$
# Average price per listing is 200$.
# Median price per listing is 125$.
# ------------ Seattle ------------
# Minimum price per listing is 0$.
# Maximum price per listing is 4000$
# Average price per listing is 161$.
# Median price per listing is 130$.
# ------------ Nashville ------------
# Minimum price per listing is 0$.
# Maximum price per listing is 78200$
# Average price per listing is 281$.
# Median price per listing is 198$.

# %% [markdown]
# Based on the provided results for three datasets (Nashville, Seattle, and NYC) using four different models (Linear Regression, Ridge Regression, Lasso Regression, and ElasticNet Regression) with the same hyperparameters, let's compare the performance and provide a brief analysis:
#
#
# * NYC:
#
# Overall, all four models (Linear Regression, Ridge, Lasso, ElasticNet) have similar performance in terms of MAE, RMSE, and R2.
# Phase-1 and Phase-2 results are consistent, indicating stability in model performance.
# The R2 values range from 0.417 to 0.421, indicating that the models can explain around 42% of the variance in the house prices in NYC.
#
#
# * Seattle:
#
# Similar to the NYC dataset, all four models demonstrate comparable MAE and RMSE values.
# The R2 scores range from 29% to 30%, indicating that the models have a moderate ability to explain the variance in house prices.
# Performance in phase 2 is slightly worse than that in phase 1 for all models, which might imply a decrease in generalization ability.
#
#
# * Nashville:
#
# The Linear Regression model performs the worst among all models, with higher MAE and RMSE values.
# The Ridge, Lasso, and ElasticNet models exhibit similar performance, with slightly better in phase 2.
# The R2 scores are relatively low, ranging from 11% to 16%, suggesting that the models have limited capability to explain the variance in house prices.
#
# Overall, the models' performance varies across the different cities' datasets. NYC shows the best performance, with relatively lower MAE and RMSE values and higher R2 scores, indicating a better ability to explain house prices. Seattle dataset exhibits lower R2 scores and Nashville dataset has the worst predictionr result, implying that the models struggle to capture the underlying patterns in these datasets. The results suggest the possibility of overfitting, particularly in Phase 2, which might require further investigation and model refinement techniques such as regularization or feature engineering to improve the models' performance on prediction and the robustness of the model.
